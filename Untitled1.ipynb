# %%
print(data.columns)
data.columns = data.columns.str.strip()
numeric_data = data.select_dtypes(include=['float64','int64'])

print(numeric_data.columns)
corr = numeric_data.corr()
print(corr)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True)

plt.title("Correlation Between Student Lifestyle Factors and Academic Pressure")

plt.show()
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.scatterplot(
x=data["On weekdays, approximately how many hours do you spend studying, working, or engaged in learning activities?"],
y=data["How much pressure do you feel from academics/work?"]
)

plt.xlabel("Study Hours")
plt.ylabel("Academic Pressure")
plt.title("Relationship Between Study Hours and Academic Pressure")

plt.show()
# Out:
# Index(['Timestamp', 'Are you 15 years or older?', 'What is your age?',
#        'Consent:', 'Age:', 'Gender:', 'Current status:', 'City/Town:',
#        'On weekdays, approximately how many hours do you spend studying, working, or engaged in learning activities?',
#        'On weekends, approximately how many hours per day do you study/work?',
#        'When do you usually start studying or working on weekdays?',
#        'When do you usually finish studying or working on weekdays?',
#        'How often do you work/study late at night (after 10 PM)?',
#        'Do you follow a fixed schedule (same timings each day)?',
#        'How regular is your daily routine?',
#        'Do you take naps during the day?',
#        'How many hours a week do you spend on extracurriculars or work?',
#        'How many hours of screen time do you have in the 2 hours before bedtime?',
#        'Do you drink coffee, tea, or other caffeine after 4 PM?',
# ...
